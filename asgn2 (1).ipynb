# %%
#1
rollno="1024170068"
L=[int(digit) * 10 for digit in rollno]
print(L)
#2
L.append(30)
L.insert(4,70)
print(L)
#3
L.remove(20)
L.pop(5)
print(L)
#4
L.sort()
print(L)
L.sort(reverse=True)
print(L)
#5
print(L[:3]," ",L[-3:])
#6
avg=sum(L)/len(L)
print(avg)
l=[i for i in L if i>avg]
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 60, 80]
# [10, 0, 20, 40, 70, 10, 70, 0, 0, 60, 80, 30]
# [10, 0, 40, 70, 10, 0, 0, 60, 80, 30]
# [0, 0, 0, 10, 10, 30, 40, 60, 70, 80]
# [80, 70, 60, 40, 30, 10, 10, 0, 0, 0]
# [80, 70, 60]   [0, 0, 0]
# 30.0
# [80, 70, 60, 40]

# %%
#1
T=(L[:8])
print(T)
print("min:",min(T),"  ","max:",max(T))
print("lowest count:",T.count(min(T)))
print("index of max:",T.index(max(T)))
#2
rev=list(T[::-1])
print(rev)
#3
a=int(input("Enter a score:"))
if a in tuple(T):
    print(T.index(a))
else:
    print("not present")
T=tuple(T)
#4
try:
    T[0]=100
except:
    print("Error because tuple is immutable; cannot be changed")
#5
fst,sec, *rem=T
print(fst,sec,rem)
# Out:
# [80, 70, 60, 40, 30, 10, 10, 0]
# min: 0    max: 80
# lowest count: 1
# index of max: 0
# [0, 10, 10, 30, 40, 60, 70, 80]
# Enter a score: 50
# not present
# Error because tuple is immutable; cannot be changed
# 80 70 [60, 40, 30, 10, 10, 0]

# %%
#1
import random
random.seed(1024170068)
a=[random.randint(100,900) for _ in range(100)]
print(a)
#2 and 3
even=[n for n in a if n%2==0]
odd=[n for n in a if n%2!=0]
b=len(even)
c=len(odd)
print("count: ",b," even numbers:",even)
print("count: ",c," odd numbers:",odd)
#4
def primes():
    if n<2:
        return false
    for i in range(2,n):
        if n%i==0:
            return False
    return True
prime=[]
for n in a:
    if primes():
        prime.append(n)
print("count: ",len(prime)," numbers: ",prime)       
#5
maxx=0
num=None
for n in a:
    count=0
    for m in a:
        if m==n:
            count+=1
    if count>maxx:
        maxx=count
        num=n
print("most freq: ",num,"\tcount: ",maxx)
# Out:
# [644, 640, 454, 152, 123, 802, 778, 881, 567, 737, 626, 487, 670, 544, 394, 223, 304, 226, 642, 443, 632, 560, 356, 523, 347, 236, 733, 611, 277, 347, 350, 744, 247, 291, 684, 838, 222, 457, 282, 690, 376, 815, 754, 295, 126, 353, 532, 434, 134, 156, 303, 872, 749, 172, 810, 247, 643, 229, 772, 866, 831, 139, 561, 265, 605, 257, 291, 424, 143, 332, 191, 578, 729, 750, 499, 582, 370, 579, 183, 515, 821, 412, 414, 687, 761, 226, 124, 656, 820, 228, 417, 721, 152, 389, 452, 617, 877, 780, 412, 326]
# count:  54  even numbers: [644, 640, 454, 152, 802, 778, 626, 670, 544, 394, 304, 226, 642, 632, 560, 356, 236, 350, 744, 684, 838, 222, 282, 690, 376, 754, 126, 532, 434, 134, 156, 872, 172, 810, 772, 866, 424, 332, 578, 750, 582, 370, 412, 414, 226, 124, 656, 820, 228, 152, 452, 780, 412, 326]
# ...

# %%
#6,7,8 and 9,10
roll_no="1024170068"
digit=[int(d) for d in roll_no]
A={d*7 for d in digit}
B={d*9 for d in digit}
print(A,B)
print(A.union(B),A.intersection(B),A.difference(B),B.difference(A),A.symmetric_difference(B),A.issubset(B),B.issuperset(A))
#11
x=int(input("Enter to discard:"))
A.discard(x)
print(A)
# Out:
# {0, 7, 42, 14, 49, 56, 28} {0, 36, 72, 9, 18, 54, 63}
# {0, 36, 7, 72, 9, 42, 14, 49, 18, 54, 56, 28, 63} {0} {7, 42, 14, 49, 56, 28} {36, 72, 9, 18, 54, 63} {7, 72, 9, 14, 18, 28, 36, 42, 49, 54, 56, 63} False False
# Enter to discard: 14
# {0, 7, 42, 49, 56, 28}

# %%
my_dict={"name":"Coral","roll_no":1024170068,"branch":"COPC","age":20,"city":"Ahmedabad"}
print(my_dict)
#1
my_dict["location"]=my_dict.pop("city")
#2
my_dict["cgpa"]=8.5
#3
my_dict["age"]+=1
#4
dict1=my_dict.copy()
dict1.pop("branch")
dict2=my_dict.copy()
del dict2["branch"]
#5
for x,y in my_dict.items():
    print(f"{x}->{y}")
#6
if "email" in my_dict:
    print("present")
else:
    print("not present")
#7
new={"name":"Akash","roll_no":1022170672,"branch":"COPC","age":22,"city":"Dubai"}
mergee={**my_dict,**new}
print(mergee)
#8
new_dict={
# Out:
# {'name': 'Coral', 'roll_no': 1024170068, 'branch': 'COPC', 'age': 20, 'city': 'Ahmedabad'}
# name->Coral
# roll_no->1024170068
# branch->COPC
# age->21
# location->Ahmedabad
# cgpa->8.5
# not present
# {'name': 'Akash', 'roll_no': 1022170672, 'branch': 'COPC', 'age': 22, 'location': 'Ahmedabad', 'cgpa': 8.5, 'city': 'Dubai'}
